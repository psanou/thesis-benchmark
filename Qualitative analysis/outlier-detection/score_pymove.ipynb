# %% [markdown]
# # Qualitative analysis of outlier detection

# %%
import pandas as pd
import pymove as pm
from pymove import MoveDataFrame
from pymove import filters
import pymove as pm
from pymove.visualization import folium as f, matplotlib as mpl
from pymove.utils import visual
from pymove.preprocessing import stay_point_detection, compression, segmentation
import numpy as np
from pyproj import Geod
from shapely.ops import nearest_points
import json
from shapely.geometry import Point, LineString, Polygon

# %% [markdown]
# ## Qualititative analysis based on the shapefile

# %% [markdown]
# ### Trajectory loading

# %%
df= pd.read_csv("../datasets/my_traj.csv")
f.plot_trajectories(MoveDataFrame(data=df, latitude='latitude', longitude='longitude', traj_id='id', datetime='time'))
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-1.12.4.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_c18092093f021b962e2ed62043e52b1b {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
#     &lt;script src=&quot;https://cdn.jsdelivr.net/gh/marslan390/BeautifyMarker/leaflet-beautify-marker-icon.min.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/marslan390/BeautifyMarker/leaflet-beautify-marker-icon.min.css&quot;/&gt;
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_c18092093f021b962e2ed62043e52b1b&quot; &gt;&lt;/div&gt;
#
#
#
#     &lt;!doctype html&gt;
#     &lt;html lang=&quot;en&quot;&gt;
#     &lt;head&gt;
#       &lt;meta charset=&quot;utf-8&quot;&gt;
#       &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width, initial-scale=1&quot;&gt;
#       &lt;link rel=&quot;stylesheet&quot;
#         href=&quot;//code.jquery.com/ui/1.12.1/themes/base/jquery-ui.css&quot;&gt;
#
#       &lt;script src=&quot;https://code.jquery.com/jquery-1.12.4.js&quot;&gt;&lt;/script&gt;
#       &lt;script src=&quot;https://code.jquery.com/ui/1.12.1/jquery-ui.js&quot;&gt;&lt;/script&gt;
#
#       &lt;script&gt;
#       $( function() {
#         $( &quot;#maplegend&quot; ).draggable({
#                         start: function (event, ui) {
#                             $(this).css({
#                                 right: &quot;auto&quot;,
#                                 top: &quot;auto&quot;,
#                                 bottom: &quot;auto&quot;
#                             });
#                         }
#                     });
#     });
#
#       &lt;/script&gt;
#     &lt;/head&gt;
#     &lt;body&gt;
#
#     &lt;div id=&#x27;maplegend&#x27; class=&#x27;maplegend&#x27;
#         style=&#x27;position: absolute; z-index:9999; border:2px solid grey;
#         background-color:rgba(255, 255, 255, 0.8); border-radius:6px;
#         padding: 10px; font-size:14px; right: 20px; bottom: 20px;&#x27;&gt;
#
#     &lt;div class=&#x27;legend-title&#x27;&gt; Color by user ID &lt;/div&gt;
#     &lt;div class=&#x27;legend-scale&#x27;&gt;
#       &lt;ul class=&#x27;legend-labels&#x27;&gt;
#         &lt;li&gt;&lt;span style=&#x27;background:#e41a1c;&#x27;&gt;&lt;/span&gt;0&lt;/li&gt;
#       &lt;/ul&gt;
#     &lt;/div&gt;
#     &lt;/div&gt;
#
#     &lt;/body&gt;
#     &lt;/html&gt;
#
#     &lt;style type=&#x27;text/css&#x27;&gt;
#       .maplegend .legend-title {
#         text-align: left;
#         margin-bottom: 5px;
#         font-weight: bold;
#         font-size: 90%;
#         }
#       .maplegend .legend-scale ul {
#         margin: 0;
#         margin-bottom: 5px;
#         padding: 0;
#         float: left;
#         list-style: none;
#         }
#       .maplegend .legend-scale ul li {
#         font-size: 80%;
#         list-style: none;
#         margin-left: 0;
#         line-height: 18px;
#         margin-bottom: 2px;
#         }
#       .maplegend ul.legend-labels li span {
#         display: block;
#         float: left;
#         height: 16px;
#         width: 30px;
#         margin-right: 5px;
#         margin-left: 0;
#         border: 1px solid #999;
#         }
#       .maplegend .legend-source {
#         font-size: 80%;
#         color: #777;
#         clear: both;
#         }
#       .maplegend a {
#         color: #777;
#         }
#     &lt;/style&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_c18092093f021b962e2ed62043e52b1b = L.map(
#                 &quot;map_c18092093f021b962e2ed62043e52b1b&quot;,
#                 {
#                     center: [50.83448324, 4.38392858],
#                     crs: L.CRS.EPSG3857,
#                     zoom: 12,
#                     zoomControl: true,
#                     preferCanvas: false,
#                 }
#             );
#             L.control.scale().addTo(map_c18092093f021b962e2ed62043e52b1b);
#
#
#
#
#
#             var tile_layer_cb97371e9ef883dafa2d5daac78dd540 = L.tileLayer(
#                 &quot;https://cartodb-basemaps-{s}.global.ssl.fastly.net/light_all/{z}/{x}/{y}.png&quot;,
#                 {&quot;attribution&quot;: &quot;\u0026copy; \u003ca target=\&quot;_blank\&quot; href=\&quot;http://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors \u0026copy; \u003ca target=\&quot;_blank\&quot; href=\&quot;http://cartodb.com/attributions\&quot;\u003eCartoDB\u003c/a\u003e, CartoDB \u003ca target=\&quot;_blank\&quot; href =\&quot;http://cartodb.com/attributions\&quot;\u003eattributions\u003c/a\u003e&quot;, &quot;detectRetina&quot;: false, &quot;maxNativeZoom&quot;: 18, &quot;maxZoom&quot;: 18, &quot;minZoom&quot;: 0, &quot;noWrap&quot;: false, &quot;opacity&quot;: 1, &quot;subdomains&quot;: &quot;abc&quot;, &quot;tms&quot;: false}
#             ).addTo(map_c18092093f021b962e2ed62043e52b1b);
#
#
#             var feature_group_b48a935b8690a1fbf4347688db805bb6 = L.featureGroup(
#                 {}
#             ).addTo(map_c18092093f021b962e2ed62043e52b1b);
#
#
#             var marker_63bd2b234bbcb57135601166895dc805 = L.marker(
#                 [50.83997769, 4.3650872],
#                 {&quot;clusteredMarker&quot;: true, &quot;color&quot;: &quot;green&quot;}
#             ).addTo(feature_group_b48a935b8690a1fbf4347688db805bb6);
#
#
#             var beautify_icon_0ebf8b0d2fedbfd2aed0938dcb6d9fb1 = new L.BeautifyIcon.icon(
#                 {&quot;backgroundColor&quot;: &quot;#e41a1c&quot;, &quot;borderColor&quot;: &quot;#000&quot;, &quot;borderWidth&quot;: 3, &quot;icon&quot;: &quot;play&quot;, &quot;iconShape&quot;: &quot;marker&quot;, &quot;innerIconStyle&quot;: &quot;&quot;, &quot;isAlphaNumericIcon&quot;: false, &quot;spin&quot;: false, &quot;textColor&quot;: &quo

# %% [markdown]
# ### Shapefile loading & Ground truth computation

# %%
from pyproj import CRS, Geod
line = "034b"
variante = 1
shapefile= pd.read_csv("datasets/shapefiles.csv", delimiter=";")
shapefile = shapefile[(shapefile["LIGNE"]==line) & (shapefile["VARIANTE"]==variante )]["Geo Shape"].values[0]
shapefile = json.loads(shapefile)

crs_utm = CRS.from_user_input(31370)
geod = crs_utm.get_geod()  # Your data may be from a different Geod.
distance = np.zeros(len(df))
nearest_points_list = []
df = df.reset_index(drop=True)
line_shape = LineString(shapefile["coordinates"]) 
for index, row in df.iterrows():
    point = Point(row["longitude"], row["latitude"])
    closest_points = nearest_points(line_shape, point)
    nearest_points_list.append(closest_points[0])
    distance[index] = geod.geometry_length(LineString(closest_points))
    
df["distance"] = distance 
#df["nearest_point"] = nearest_points_list
mean = df["distance"].mean()
median = df["distance"].median()
std = df["distance"].std()
k=1.5
threshold = median + k * std
#df["nearest_point"] = nearest_points_list
print(mean, std)
outliers = df[df["distance"] > threshold]
is_normal = np.zeros(len(df))
for i in range(len(df['time'].values)):
    if df['time'].values[i] not in outliers['time'].values:
        is_normal[i] = 1
df["is normal"] = is_normal > 0
df
# Out:
# 6.99931376823816 6.984997264301602
#                           time   latitude  longitude  id  distance  is normal
# 0    2023-06-30 13:34:13+00:00  50.839978   4.365087   0  6.434879       True
# 1    2023-06-30 13:34:15+00:00  50.840059   4.365243   0  6.241407       True
# 2    2023-06-30 13:34:17+00:00  50.840115   4.365356   0  6.274832       True
# 3    2023-06-30 13:34:55+00:00  50.840184   4.365509   0  6.957367       True
# 4    2023-06-30 13:34:58+00:00  50.840269   4.365628   0  4.605384       True
# ..                         ...        ...        ...  ..       ...        ...
# 312  2023-06-30 13:55:35+00:00  50.821950   4.404838   0  4.315869       True
# 313  2023-06-30 13:55:37+00:00  50.821916   4.405050   0  1.384736       True
# 314  2023-06-30 13:55:39+00:00  50.821854   4.405199   0  3.199198       True
# 315  2023-06-30 13:55:41+00:00  50.821825   4.405334   0  2.081433       True
# 316  2023-06-30 13:55:44+00:00  50.821776   4.405521   0  1.418874       True
#
# [317 rows x 6 columns]

# %%
trajectory_df = MoveDataFrame(data=df, latitude='latitude', longitude='longitude', traj_id='id', datetime='time')

# %% [markdown]
# #### Speed based method

# %%
cleaned_df = filters.clean_gps_speed_max_radius(trajectory_df,speed_max=9)
cleaned_df.to_csv('csv_results/cleaned_df_pymove_trip.csv', index=False)
cleaned_df
# Out:
# VBox(children=(HTML(value=''), IntProgress(value=0, max=1)))
#      id            datetime        lat       lon  distance  is normal  \
# 0     0 2023-06-30 13:34:13  50.839978  4.365087  6.434879       True
# 1     0 2023-06-30 13:34:15  50.840059  4.365243  6.241407       True
# 2     0 2023-06-30 13:34:17  50.840115  4.365356  6.274832       True
# 3     0 2023-06-30 13:34:55  50.840184  4.365509  6.957367       True
# 4     0 2023-06-30 13:34:58  50.840269  4.365628  4.605384       True
# ..   ..                 ...        ...       ...       ...        ...
# 312   0 2023-06-30 13:55:35  50.821950  4.404838  4.315869       True
# 313   0 2023-06-30 13:55:37  50.821916  4.405050  1.384736       True
# 314   0 2023-06-30 13:55:39  50.821854  4.405199  3.199198       True
# 315   0 2023-06-30 13:55:41  50.821825  4.405334  2.081433       True
# 316   0 2023-06-30 13:55:44  50.821776  4.405521  1.418874       True
#
#      dist_to_prev  time_to_prev  speed_to_prev
# 0             NaN           NaN            NaN
# 1       14.206847           2.0       7.103424
# 2       10.097854           2.0       5.048927
# 3       13.190598          38.0       0.347121
# 4       12.599354           3.0       4.199785
# ..            ...           ...            ...
# 312     15.924017           2.0       7.962009
# 313     15.397282           2.0       7.698641
# 314     12.475083           2.0       6.237542
# 315     10.032891           2.0       5.016446
# 316     14.250324           3.0       4.750108
#
# [248 rows x 9 columns]

# %%
outlier_df = pd.DataFrame(trajectory_df).merge(pd.DataFrame(cleaned_df).drop_duplicates(), on=['datetime'], how='left', indicator=True)
outlier_df = outlier_df[outlier_df["_merge"] == "left_only"]
outlier_df
# Out:
#                datetime      lat_x     lon_x  id_x  distance_x  is normal_x  \
# 32  2023-06-30 13:37:09  50.839815  4.369780     0    3.761563         True
# 33  2023-06-30 13:37:11  50.839754  4.369984     0    2.121975         True
# 38  2023-06-30 13:37:20  50.839453  4.370871     0    9.762360         True
# 39  2023-06-30 13:37:21  50.839367  4.370965     0   16.845646        False
# 40  2023-06-30 13:37:23  50.839255  4.371156     0   24.545542        False
# ..                  ...        ...       ...   ...         ...          ...
# 297 2023-06-30 13:55:07  50.823109  4.402318     0    4.971081         True
# 298 2023-06-30 13:55:09  50.823024  4.402457     0    4.354680         True
# 302 2023-06-30 13:55:16  50.822703  4.403070     0    4.721914         True
# 303 2023-06-30 13:55:17  50.822627  4.403169     0    2.393939         True
# 304 2023-06-30 13:55:19  50.822513  4.403351     0    0.909013         True
#
#      id_y  lat_y  lon_y  distance_y is normal_y  dist_to_prev  time_to_prev  \
# 32    NaN    NaN    NaN         NaN         NaN           NaN           NaN
# 33    NaN    NaN    NaN         NaN         NaN           NaN           NaN
# 38    NaN    NaN    NaN         NaN         NaN           NaN           NaN
# 39    NaN    NaN    NaN         NaN         NaN           NaN           NaN
# 40    NaN    NaN    NaN         NaN         NaN           NaN           NaN
# ..    ...    ...    ...         ...         ...           ...           ...
# 297   NaN    NaN    NaN         NaN         NaN           NaN           NaN
# 298   NaN    NaN    NaN         NaN         NaN           NaN           NaN
# 302   NaN    NaN    NaN         NaN         NaN           NaN           NaN
# 303   NaN    NaN    NaN         NaN         NaN           NaN           NaN
# 304   NaN    NaN    NaN         NaN         NaN           NaN           NaN
#
#      speed_to_prev     _merge
# 32             NaN  left_only
# 33             NaN  left_only
# 38             NaN  left_only
# 39             NaN  left_only
# 40             NaN  left_only
# ..             ...        ...
# 297            NaN  left_only
# 298            NaN  left_only
# 302            NaN  left_only
# 303            NaN  left_only
# 304            NaN  left_only
#
# [69 rows x 15 columns]

# %%
TP = len(cleaned_df[cleaned_df["is normal"] == True])
FP = len(cleaned_df[cleaned_df["is normal"] == False])
TN = len(outlier_df[outlier_df["is normal_x"] == False])
FN = len(outlier_df[outlier_df["is normal_x"] == True])
P = TP / (TP + FP)
A = (TP + TN) / (TP + TN + FP + FN)
R = TP / (TP + FN)
F1 = 2 * (P * R) / (P + R)
print("TP:{}\nFP:{}\nTN:{}\nFN:{}".format(TP,FP,TN,FN))
print("Precision:", round(P,3))
print("Accuracy::",round(A,3))
print("Recall:", round(R,3))
print("F1:", round(F1,3))
# Out:
# TP:219
# FP:29
# TN:6
# FN:63
# Precision: 0.883
# Accuracy:: 0.71
# Recall: 0.777
# F1: 0.826

# %% [markdown]
# ## Qualititative analysis based on the introduction of outliers

# %%
df= pd.read_csv("datasets/berlinMOD_with_outlier.csv")
trajectory_df = MoveDataFrame(data=df, latitude='latitude', longitude='longitude', traj_id='id', datetime='time')

# %% [markdown]
# #### speed based method

# %%
cleaned_df = filters.clean_gps_speed_max_radius(trajectory_df,speed_max=25)
cleaned_df
cleaned_df.to_csv('csv_results/cleaned_df_pymove_MOD.csv', index=False)
# Out:
# VBox(children=(HTML(value=''), IntProgress(value=0, max=1)))

# %%
outlier_df = pd.DataFrame(trajectory_df).merge(pd.DataFrame(cleaned_df).drop_duplicates(), on=['datetime'], how='left', indicator=True)
outlier_df = outlier_df[outlier_df["_merge"] == "left_only"]
outlier_df
# Out:
#       id_x                   datetime      lat_x     lon_x  OLD_Latitude_x  \
# 11       8 2020-06-01 08:56:28.127688  50.861891  4.520971       50.861891
# 12       8 2020-06-01 08:56:29.028663  50.861911  4.465593       50.861911
# 13       8 2020-06-01 08:56:32.628663  50.861987  4.465161       50.861987
# 81       8 2020-06-01 08:58:00.120432  50.918525  4.463031       50.863289
# 82       8 2020-06-01 08:58:01.200432  50.863343  4.462927       50.863343
# ...    ...                        ...        ...       ...             ...
# 4859     8 2020-06-04 21:55:29.454902  50.863380  4.462846       50.863380
# 4860     8 2020-06-04 21:55:29.829902  50.863364  4.462883       50.863364
# 4871     8 2020-06-04 21:55:44.586342  50.863171  4.557394       50.863171
# 4872     8 2020-06-04 21:55:50.239350  50.863164  4.463236       50.863164
# 4873     8 2020-06-04 21:55:51.605294  50.863142  4.463265       50.863142
#
#       OLD_Longitude_x  is normal_x  lat_var_x  lon_var_x  id_y  ...  lon_y  \
# 11           4.465701        False   0.000000   0.055269   NaN  ...    NaN
# 12           4.465593         True   0.000000   0.000000   NaN  ...    NaN
# 13           4.465161         True   0.000000   0.000000   NaN  ...    NaN
# 81           4.463031        False   0.055235   0.000000   NaN  ...    NaN
# 82           4.462927         True   0.000000   0.000000   NaN  ...    NaN
# ...               ...          ...        ...        ...   ...  ...    ...
# 4859         4.462846         True   0.000000   0.000000   NaN  ...    NaN
# 4860         4.462883         True   0.000000   0.000000   NaN  ...    NaN
# 4871         4.463224        False   0.000000   0.094170   NaN  ...    NaN
# 4872         4.463236         True   0.000000   0.000000   NaN  ...    NaN
# 4873         4.463265         True   0.000000   0.000000   NaN  ...    NaN
#
#       OLD_Latitude_y  OLD_Longitude_y  is normal_y lat_var_y  lon_var_y  \
# 11               NaN              NaN          NaN       NaN        NaN
# 12               NaN              NaN          NaN       NaN        NaN
# 13               NaN              NaN          NaN       NaN        NaN
# 81               NaN              NaN          NaN       NaN        NaN
# 82               NaN              NaN          NaN       NaN        NaN
# ...              ...              ...          ...       ...        ...
# 4859             NaN              NaN          NaN       NaN        NaN
# 4860             NaN              NaN          NaN       NaN        NaN
# 4871             NaN              NaN          NaN       NaN        NaN
# 4872             NaN              NaN          NaN       NaN        NaN
# 4873             NaN              NaN          NaN       NaN        NaN
#
#       dist_to_prev  time_to_prev  speed_to_prev     _merge
# 11             NaN           NaN            NaN  left_only
# 12             NaN           NaN            NaN  left_only
# 13             NaN           NaN            NaN  left_only
# 81             NaN           NaN            NaN  left_only
# 82             NaN           NaN            NaN  left_only
# ...            ...           ...            ...        ...
# 4859           NaN           NaN            NaN  left_only
# 4860           NaN           NaN            NaN  left_only
# 4871           NaN           NaN            NaN  left_only
# 4872           NaN           NaN            NaN  left_only
# 4873           NaN           NaN            NaN  left_only
#
# [292 rows x 21 columns]

# %%
TP = len(cleaned_df[cleaned_df["is normal"] == True])
FP = len(cleaned_df[cleaned_df["is normal"] == False])
TN = len(outlier_df[outlier_df["is normal_x"] == False])
FN = len(outlier_df[outlier_df["is normal_x"] == True])
P = TP / (TP + FP)
A = (TP + TN) / (TP + TN + FP + FN)
R = TP / (TP + FN)
F1 = 2 * (P * R) / (P + R)
print("TP:{}\nFP:{}\nTN:{}\nFN:{}".format(TP,FP,TN,FN))
print("Precision:", round(P,3))
print("Accuracy::",round(A,3))
print("Recall:", round(R,3))
print("F1:", round(F1,3))
# Out:
# TP:4650
# FP:0
# TN:99
# FN:193
# Precision: 1.0
# Accuracy:: 0.961
# Recall: 0.96
# F1: 0.98
