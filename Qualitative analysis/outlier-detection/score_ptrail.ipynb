# %% [markdown]
# # Qualitative analysis of outlier detection

# %%
import pandas as pd
from ptrail.core.TrajectoryDF import PTRAILDataFrame
from ptrail.features.temporal_features import TemporalFeatures as temporal
from ptrail.features.kinematic_features import KinematicFeatures as kinematic
from ptrail.preprocessing.filters import Filters as filt
from ptrail.visualization import TrajPlotter
import ptrail.utilities.constants as const
import numpy as np
import folium
from pyproj import Geod
from shapely.geometry import Point, LineString
from shapely.ops import nearest_points
import json

# %%
LAT = "lat"
LONG = "lng"
ID = 'tid'
def visualization(trajectory_df,color="blue"):    
    m2 = folium.Map(location=[(np.max(trajectory_df[const.LAT])+np.min(trajectory_df[const.LAT]))/2, (np.max(trajectory_df[const.LONG])+np.min(trajectory_df[const.LONG]))/2], zoom_start=14, width="70%", height="100") # create the map
    ids = trajectory_df.index.get_level_values('traj_id').unique() # get all uniques ids
    for i in ids: # add a line per trajectory and avoid linked trajectories
        tmp_df = trajectory_df[trajectory_df.index.get_level_values('traj_id') == i]
        coords = [zip(tmp_df[const.LAT], tmp_df[const.LONG])]
        folium.PolyLine(coords,
                        color=color,
                        weight=4,
                        opacity=0.7).add_to(m2)
    return m2

# %% [markdown]
# ## Qualititative analysis based on the shapefile

# %% [markdown]
# ### Trajectory loading

# %%
threshold = 3
df= pd.read_csv("datasets/my_traj.csv")
visualization(PTRAILDataFrame(data_set = df, latitude='latitude', longitude='longitude', datetime='time', traj_id='id'),"#0080FF")
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-1.12.4.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_6106a2c4276645f690d1081f1ff36a45 {
#                     position: relative;
#                     width: 70.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_6106a2c4276645f690d1081f1ff36a45&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_6106a2c4276645f690d1081f1ff36a45 = L.map(
#                 &quot;map_6106a2c4276645f690d1081f1ff36a45&quot;,
#                 {
#                     center: [50.831196105000004, 4.38530418],
#                     crs: L.CRS.EPSG3857,
#                     zoom: 14,
#                     zoomControl: true,
#                     preferCanvas: false,
#                 }
#             );
#
#
#
#
#
#             var tile_layer_b65ec699b9dcd737d21917861bd82461 = L.tileLayer(
#                 &quot;https://{s}.tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {&quot;attribution&quot;: &quot;Data by \u0026copy; \u003ca target=\&quot;_blank\&quot; href=\&quot;http://openstreetmap.org\&quot;\u003eOpenStreetMap\u003c/a\u003e, under \u003ca target=\&quot;_blank\&quot; href=\&quot;http://www.openstreetmap.org/copyright\&quot;\u003eODbL\u003c/a\u003e.&quot;, &quot;detectRetina&quot;: false, &quot;maxNativeZoom&quot;: 18, &quot;maxZoom&quot;: 18, &quot;minZoom&quot;: 0, &quot;noWrap&quot;: false, &quot;opacity&quot;: 1, &quot;subdomains&quot;: &quot;abc&quot;, &quot;tms&quot;: false}
#             ).addTo(map_6106a2c4276645f690d1081f1ff36a45);
#
#
#             var poly_line_1d6d3a9fc55790beb8a27a9779c183e6 = L.polyline(
#                 [[[50.84018428, 4.36550891], [50.84026877, 4.36562847], [50.84034369, 4.36572485], [50.84044181, 4.36582994], [50.84053458, 4.36590023], [50.84061648, 4.36596223], [50.84060409, 4.36613066], [50.84055398, 4.36628251], [50.84049899, 4.36644194], [50.84043694, 4.36659357], [50.84036558, 4.36675427], [50.84029949, 4.36687319], [50.8402165, 4.36692896], [50.84017535, 4.36707382], [50.84013493, 4.36732135], [50.84015038, 4.36754044], [50.84006308, 4.36772101], [50.83997771, 4.36789239], [50.83992538, 4.36801023], [50.83994059, 4.36816754], [50.84000367, 4.36830168], [50.84006331, 4.36841765], [50.84004483, 4.36860735], [50.84000734, 4.36878936], [50.84000764, 4.3690224], [50.84000914, 4.36920243], [50.83998387, 4.36938789], [50.83992815, 4.36950006], [50.83988961, 4.36963538], [50.83981469, 4.36977982], [50.83975445, 4.36998403], [50.83968383, 4.37016771], [50.83965518, 4.37035694], [50.83958391, 4.37054941], [50.83954061, 4.37074728], [50.83945318, 4.37087079], [50.83936716, 4.37096517], [50.8392546, 4.37115606], [50.83916947, 4.37133775], [50.83909852, 4.37147877], [50.83903078, 4.37163777], [50.83905684, 4.37178122], [50.83917492, 4.37187007], [50.83921491, 4.3719986], [50.83915269, 4.37213335], [50.83908273, 4.37231956], [50.83903866, 4.37248412], [50.83900094, 4.37266668], [50.8389711, 4.37281696], [50.83888481, 4.3728595], [50.83876465, 4.37282059], [50.83867512, 4.3728068], [50.83856848, 4.37276047], [50.83842946, 4.37277472], [50.83832393, 4.372739], [50.83822922, 4.37270737], [50.83809172, 4.37266473], [50.83798956, 4.3726336], [50.83791696, 4.37252073], [50.83781575, 4.37242681], [50.83771123, 4.37233015], [50.83762455, 4.37209226], [50.83754945, 4.37195082], [50.83740073, 4.37181574], [50.83726903, 4.37167769], [50.83715116, 4.37155146], [50.83704816, 4.37144221], [50.83697346, 4.37132344], [50.83685746, 4.37116559], [50.83678141, 4.37108119], [50.83668405, 4.37102208], [50.83658812, 4.37100577], [50.83646686, 4.37099947], [50.83639389, 4.3710999], [50.83631156, 4.37119878], [50.83620855, 4.3712519], [50.83625922, 4.3714141], [50.83616713, 4.37141469], [50.83607425, 4.37137634], [50.83598022, 4.3713927], [50.83596981, 4.37153728], [50.83588489, 4.37178558], [50.83592838, 4.37206725], [50.83591319, 4.37223001], [50.83588761, 4.37239493], [50.83601676, 4.37236584], [50.83592629, 4.37239915], [50.83627378, 4.37240136], [50.83642243, 4.37279678], [50.83611751, 4.37281093], [50.83610681, 4.37313828], [50.83604434, 4.37331972], [50.83608344, 4.3735259], [50.83602948, 4.37368998], [50.83600851, 4.37383127], [50.8358572, 4.374173], [50.83581476, 4.3743896], [50.83578143, 4.37461816], [50.8357766, 4.37482907], [50.83574675, 4.37502528], [50.83573204, 4.37523101], [50.83570146, 4.37545713], [50.83567685, 4.37568759], [50.83566847, 4.3758629], [50.83566775, 4.37604265], [50.83568676, 4.37623068], [50.83567983, 4.37642243], [50.83566479, 4.37656895], [50.83567009, 4.37677529], [50.83570644, 4.37695045], [50.83574285, 4.37709535], [50.83578632, 4.37727565], [50.83581059, 4.37741236], [50.83582602, 4.3775702], [50.83572847, 4.37718634], [50.83574849, 4.37732695], [50.83576467, 4.37747824], [50.83568905, 4.3776718], [50.83570977, 4.37790905], [50.83571406, 4.37811266], [50.8357295, 4.37835684], [50.83577068, 4.37852527], [50.83580366, 4.37870705], [50.83580988, 4.37886009], [50.83589362, 4.37866855], [50.8359165, 4.37901709], [50.83596189, 4.37915593], [50.83595786, 4.37934247], [50.83593385, 4.37952955], [50.83587145, 4.37973885], [50.83582931, 4.37997603], [50.83578896, 4.38013981], [50.83575159, 4.3802808], [50.83567325, 4.38038755], [50.83562943, 4.3805543], [50.83557281, 4.38070382], [50.83552448, 4.38087551], [50.83547926, 4.38099882], [50.83542408, 4.38113558], [50.83535096, 4.38133729], [50.83529936, 4.38151301], [50.83524559, 4.38167556], [50.83522967, 4.38190476], [50.83521253, 4.38209545], [50.83511085, 4.38217074], [50.8349952, 4.38229181], [50.83491337, 4.38244811], [50.83485709, 4.38261435], [50.8348236, 4 ...

# %% [markdown]
# ### Shapefile loading & Ground truth computation

# %%
from pyproj import CRS, Geod
line = "034b"
variante = 1
shapefile= pd.read_csv("datasets/shapefiles.csv", delimiter=";")
shapefile = shapefile[(shapefile["LIGNE"]==line) & (shapefile["VARIANTE"]==variante )]["Geo Shape"].values[0]
shapefile = json.loads(shapefile)

crs_utm = CRS.from_user_input(31370)
geod = crs_utm.get_geod()  # Your data may be from a different Geod.
distance = np.zeros(len(df))
nearest_points_list = []
df = df.reset_index(drop=True)
line_shape = LineString(shapefile["coordinates"]) 
for index, row in df.iterrows():
    point = Point(row["longitude"], row["latitude"])
    closest_points = nearest_points(line_shape, point)
    nearest_points_list.append(closest_points[0])
    distance[index] = geod.geometry_length(LineString(closest_points))
    
df["distance"] = distance 
#df["nearest_point"] = nearest_points_list
mean = df["distance"].mean()
median = df["distance"].median()
std = df["distance"].std()
k=1.5
threshold = median + k * std
#df["nearest_point"] = nearest_points_list
print(mean, std)
outliers = df[df["distance"] > threshold]
is_normal = np.zeros(len(df))
for i in range(len(df['time'].values)):
    if df['time'].values[i] not in outliers['time'].values:
        is_normal[i] = 1
df["is normal"] = is_normal > 0
df
# Out:
# 6.99931376823816 6.984997264301602
#                           time   latitude  longitude  id  distance  is normal
# 0    2023-06-30 13:34:13+00:00  50.839978   4.365087   0  6.434879       True
# 1    2023-06-30 13:34:15+00:00  50.840059   4.365243   0  6.241407       True
# 2    2023-06-30 13:34:17+00:00  50.840115   4.365356   0  6.274832       True
# 3    2023-06-30 13:34:55+00:00  50.840184   4.365509   0  6.957367       True
# 4    2023-06-30 13:34:58+00:00  50.840269   4.365628   0  4.605384       True
# ..                         ...        ...        ...  ..       ...        ...
# 312  2023-06-30 13:55:35+00:00  50.821950   4.404838   0  4.315869       True
# 313  2023-06-30 13:55:37+00:00  50.821916   4.405050   0  1.384736       True
# 314  2023-06-30 13:55:39+00:00  50.821854   4.405199   0  3.199198       True
# 315  2023-06-30 13:55:41+00:00  50.821825   4.405334   0  2.081433       True
# 316  2023-06-30 13:55:44+00:00  50.821776   4.405521   0  1.418874       True
#
# [317 rows x 6 columns]

# %%
trajectory_df = PTRAILDataFrame(data_set = df, latitude='latitude', longitude='longitude', datetime='time', traj_id='id')
trajectory_df
# Out:
#                                          lat       lon  distance  is normal
# traj_id DateTime
# 0       2023-06-30 13:34:13+00:00  50.839978  4.365087  6.434879       True
#         2023-06-30 13:34:15+00:00  50.840059  4.365243  6.241407       True
#         2023-06-30 13:34:17+00:00  50.840115  4.365356  6.274832       True
#         2023-06-30 13:34:55+00:00  50.840184  4.365509  6.957367       True
#         2023-06-30 13:34:58+00:00  50.840269  4.365628  4.605384       True
# ...                                      ...       ...       ...        ...
#         2023-06-30 13:55:35+00:00  50.821950  4.404838  4.315869       True
#         2023-06-30 13:55:37+00:00  50.821916  4.405050  1.384736       True
#         2023-06-30 13:55:39+00:00  50.821854  4.405199  3.199198       True
#         2023-06-30 13:55:41+00:00  50.821825  4.405334  2.081433       True
#         2023-06-30 13:55:44+00:00  50.821776  4.405521  1.418874       True
#
# [317 rows x 4 columns]

# %% [markdown]
# #### Hampel based method

# %%
trajectory_df = kinematic.create_speed_column(trajectory_df)
trajectory_df
# Out:
#                                          lat       lon  distance  is normal  \
# traj_id DateTime
# 0       2023-06-30 13:34:13+00:00  50.839978  4.365087  6.434879       True
#         2023-06-30 13:34:15+00:00  50.840059  4.365243  6.241407       True
#         2023-06-30 13:34:17+00:00  50.840115  4.365356  6.274832       True
#         2023-06-30 13:34:55+00:00  50.840184  4.365509  6.957367       True
#         2023-06-30 13:34:58+00:00  50.840269  4.365628  4.605384       True
# ...                                      ...       ...       ...        ...
#         2023-06-30 13:55:35+00:00  50.821950  4.404838  4.315869       True
#         2023-06-30 13:55:37+00:00  50.821916  4.405050  1.384736       True
#         2023-06-30 13:55:39+00:00  50.821854  4.405199  3.199198       True
#         2023-06-30 13:55:41+00:00  50.821825  4.405334  2.081433       True
#         2023-06-30 13:55:44+00:00  50.821776  4.405521  1.418874       True
#
#                                     Distance     Speed
# traj_id DateTime
# 0       2023-06-30 13:34:13+00:00        NaN       NaN
#         2023-06-30 13:34:15+00:00  14.206847  7.103424
#         2023-06-30 13:34:17+00:00  10.097854  5.048927
#         2023-06-30 13:34:55+00:00  13.190598  0.347121
#         2023-06-30 13:34:58+00:00  12.599354  4.199785
# ...                                      ...       ...
#         2023-06-30 13:55:35+00:00  15.924017  7.962009
#         2023-06-30 13:55:37+00:00  15.397282  7.698641
#         2023-06-30 13:55:39+00:00  12.475083  6.237542
#         2023-06-30 13:55:41+00:00  10.032891  5.016446
#         2023-06-30 13:55:44+00:00  14.250324  4.750108
#
# [317 rows x 6 columns]

# %%
cleaned_df = filt.hampel_outlier_detection(trajectory_df, column_name='Speed')
cleaned_df
cleaned_df.to_csv('csv_results/cleaned_df_ptrail_hampel_trip.csv', index=False)

#visualization(cleaned_df,"#FF00FF")
# Out:
# Process Process-2:
# multiprocessing.pool.RemoteTraceback:
# """
# Traceback (most recent call last):
#   File "/home/pierre-cedric/miniconda3/envs/ptrail/lib/python3.9/multiprocessing/pool.py", line 125, in worker
#     result = (True, func(*args, **kwds))
#   File "/home/pierre-cedric/miniconda3/envs/ptrail/lib/python3.9/multiprocessing/pool.py", line 51, in starmapstar
#     return list(itertools.starmap(args[0], args[1]))
#   File "/home/pierre-cedric/miniconda3/envs/ptrail/lib/python3.9/site-packages/ptrail/preprocessing/helpers.py", line 390, in hampel_help
#     to_return = df.drop(df.index[outlier_indices])
#   File "/home/pierre-cedric/miniconda3/envs/ptrail/lib/python3.9/site-packages/pandas/core/indexes/base.py", line 5382, in __getitem__
#     result = getitem(key)
# IndexError: only integers, slices (`:`), ellipsis (`...`), numpy.newaxis (`None`) and integer or boolean arrays are valid indices
# """
#
# The above exception was the direct cause of the following exception:
#
# Traceback (most recent call last):
#   File "/home/pierre-cedric/miniconda3/envs/ptrail/lib/python3.9/multiprocessing/process.py", line 315, in _bootstrap
#     self.run()
#   File "/home/pierre-cedric/miniconda3/envs/ptrail/lib/python3.9/multiprocessing/process.py", line 108, in run
#     self._target(*self._args, **self._kwargs)
#   File "/home/pierre-cedric/miniconda3/envs/ptrail/lib/python3.9/site-packages/ptrail/preprocessing/filters.py", line 754, in _hampel
#     final = small_pool.starmap(helper.hampel_help,
#   File "/home/pierre-cedric/miniconda3/envs/ptrail/lib/python3.9/multiprocessing/pool.py", line 372, in starmap
#     return self._map_async(func, iterable, starmapstar, chunksize).get()
#   File "/home/pierre-cedric/miniconda3/envs/ptrail/lib/python3.9/multiprocessing/pool.py", line 771, in get
#     raise self._value
# IndexError: only integers, slices (`:`), ellipsis (`...`), numpy.newaxis (`None`) and integer or boolean arrays are valid indices
# /home/pierre-cedric/miniconda3/envs/ptrail/lib/python3.9/site-packages/ptrail/preprocessing/filters.py:726: UserWarning: If kinematic features have been generated on the dataframe, then make sure to generate them again as outlier detection drops the point from the dataframe and does not run the kinematic features again.
#   warnings.warn("If kinematic features have been generated on the dataframe, then make "
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[7], line 1
# ----> 1 cleaned_df = filt.hampel_outlier_detection(trajectory_df, column_name='Speed')
#       2 cleaned_df
#       3 cleaned_df.to_csv('csv_results/cleaned_df_ptrail_hampel_trip.csv', index=False)
#
# File ~/miniconda3/envs/ptrail/lib/python3.9/site-packages/ptrail/preprocessing/filters.py:731, in Filters.hampel_outlier_detection(dataframe, column_name)
#     726 warnings.warn("If kinematic features have been generated on the dataframe, then make "
#     727               "sure to generate them again as outlier detection drops the point from "
#     728               "the dataframe and does not run the kinematic features again.")
#     730 # Convert the results back to PTRAILDataFrame and return the resultant dataframe.
# --> 731 return PTRAILDataFrame(pd.concat(return_list),
#     732                        const.LAT, const.LONG, const.DateTime, const.TRAJECTORY_ID)
#
# File ~/miniconda3/envs/ptrail/lib/python3.9/site-packages/pandas/core/reshape/concat.py:380, in concat(objs, axis, join, ignore_index, keys, levels, names, verify_integrity, sort, copy)
#     377 elif copy and using_copy_on_write():
#     378     copy = False
# --> 380 op = _Concatenator(
#     381     objs,
#     382     axis=axis,
#     383     ignore_index=ignore_index,
#     384     join=join,
#     385     keys=keys,
#     386     levels=levels,
#     387     names=names,
#     388     verify_integrity=verify_integrity,
#     389     copy=copy,
#     390     sort=sort,
#     391 )
#     393 return op.get_result()
#
# File ~/miniconda3/envs/ptrail/lib/python3.9/site-packages/pandas/core/reshape/concat.py:443, in _Concatenator.__init__(self, objs, axis, join, keys, levels, names, ignore_index, verify_integrity, copy, sort)
#     440 self.verify_integrity = verify_integrity
#     441 self.copy = copy
# --> 443 objs, keys = self._clean_keys_and_objs(objs, keys)
#     445 # figure out what our result ndim is going to be
#     446 ndims = self._get_ndims(objs)
#
# File ~/miniconda3/envs/ptrail/lib/python3.9/site-packages/pandas/core/reshape/concat.py:505, in _Concatenator._clean_keys_and_objs(self, objs, keys)
#     502     objs_list = list(objs)
#     504 if len(objs_list) == 0:
# --> 505     raise ValueError("No objects to concatenate")
#     507 if keys is None:
#     508     objs_list = list(com.not_none(*objs_list))
#
# ValueError: No objects to concatenate

# %%
outlier_df = trajectory_df.reset_index().merge(cleaned_df.reset_index(), on=['DateTime'], how='left', indicator=True)
outlier_df = outlier_df[outlier_df["_merge"] == "left_only"]
outlier_df
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[11], line 1
# ----> 1 outlier_df = trajectory_df.reset_index().merge(cleaned_df.reset_index(), on=['DateTime'], how='left', indicator=True)
#       2 outlier_df = outlier_df[outlier_df["_merge"] == "left_only"]
#       3 outlier_df
#
# NameError: name 'cleaned_df' is not defined

# %%
TP = len(cleaned_df[cleaned_df["is normal"] == True])
FP = len(cleaned_df[cleaned_df["is normal"] == False])
TN = len(outlier_df[outlier_df["is normal_x"] == False])
FN = len(outlier_df[outlier_df["is normal_x"] == True])

print("TP:{}\nFP:{}\nTN:{}\nFN:{}".format(TP,FP,TN,FN))
print("Precision:", TP / (TP + FP))
print("Accuracy::",(TP + TN) / (TP + TN + FP + FN))
print("Recall:", TP / (TP + FN))
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[12], line 1
# ----> 1 TP = len(cleaned_df[cleaned_df["is normal"] == True])
#       2 FP = len(cleaned_df[cleaned_df["is normal"] == False])
#       3 TN = len(outlier_df[outlier_df["is normal_x"] == False])
#
# NameError: name 'cleaned_df' is not defined

# %% [markdown]
# #### IQR based  method

# %%
cleaned_df = filt.filter_outliers_by_consecutive_speed(dataframe=trajectory_df)
visualization(cleaned_df,"#FF00FF")
cleaned_df.to_csv('csv_results/cleaned_df_ptrail_iqr_trip.csv', index=False)
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-1.12.4.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_5c9786b65db13d04c8dfe0830cde509f {
#                     position: relative;
#                     width: 70.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_5c9786b65db13d04c8dfe0830cde509f&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_5c9786b65db13d04c8dfe0830cde509f = L.map(
#                 &quot;map_5c9786b65db13d04c8dfe0830cde509f&quot;,
#                 {
#                     center: [50.831196105000004, 4.385382055],
#                     crs: L.CRS.EPSG3857,
#                     zoom: 14,
#                     zoomControl: true,
#                     preferCanvas: false,
#                 }
#             );
#
#
#
#
#
#             var tile_layer_c3958ca3dee0c66bc93502f4a5a6a049 = L.tileLayer(
#                 &quot;https://{s}.tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {&quot;attribution&quot;: &quot;Data by \u0026copy; \u003ca target=\&quot;_blank\&quot; href=\&quot;http://openstreetmap.org\&quot;\u003eOpenStreetMap\u003c/a\u003e, under \u003ca target=\&quot;_blank\&quot; href=\&quot;http://www.openstreetmap.org/copyright\&quot;\u003eODbL\u003c/a\u003e.&quot;, &quot;detectRetina&quot;: false, &quot;maxNativeZoom&quot;: 18, &quot;maxZoom&quot;: 18, &quot;minZoom&quot;: 0, &quot;noWrap&quot;: false, &quot;opacity&quot;: 1, &quot;subdomains&quot;: &quot;abc&quot;, &quot;tms&quot;: false}
#             ).addTo(map_5c9786b65db13d04c8dfe0830cde509f);
#
#
#             var poly_line_a0f9d44753d967b8850f2cd9a9fcd6d5 = L.polyline(
#                 [[[50.84026877, 4.36562847], [50.84034369, 4.36572485], [50.84044181, 4.36582994], [50.84053458, 4.36590023], [50.84061648, 4.36596223], [50.84060409, 4.36613066], [50.84055398, 4.36628251], [50.84049899, 4.36644194], [50.84043694, 4.36659357], [50.84036558, 4.36675427], [50.84029949, 4.36687319], [50.8402165, 4.36692896], [50.84017535, 4.36707382], [50.84013493, 4.36732135], [50.84015038, 4.36754044], [50.84006308, 4.36772101], [50.83997771, 4.36789239], [50.83992538, 4.36801023], [50.83994059, 4.36816754], [50.84000367, 4.36830168], [50.84006331, 4.36841765], [50.84004483, 4.36860735], [50.84000734, 4.36878936], [50.84000764, 4.3690224], [50.84000914, 4.36920243], [50.83998387, 4.36938789], [50.83992815, 4.36950006], [50.83988961, 4.36963538], [50.83981469, 4.36977982], [50.83975445, 4.36998403], [50.83968383, 4.37016771], [50.83965518, 4.37035694], [50.83958391, 4.37054941], [50.83954061, 4.37074728], [50.83945318, 4.37087079], [50.83936716, 4.37096517], [50.8392546, 4.37115606], [50.83916947, 4.37133775], [50.83909852, 4.37147877], [50.83903078, 4.37163777], [50.83905684, 4.37178122], [50.83921491, 4.3719986], [50.83915269, 4.37213335], [50.83908273, 4.37231956], [50.83903866, 4.37248412], [50.83900094, 4.37266668], [50.8389711, 4.37281696], [50.83888481, 4.3728595], [50.83876465, 4.37282059], [50.83867512, 4.3728068], [50.83856848, 4.37276047], [50.83842946, 4.37277472], [50.83832393, 4.372739], [50.83822922, 4.37270737], [50.83809172, 4.37266473], [50.83798956, 4.3726336], [50.83791696, 4.37252073], [50.83781575, 4.37242681], [50.83771123, 4.37233015], [50.83754945, 4.37195082], [50.83740073, 4.37181574], [50.83726903, 4.37167769], [50.83715116, 4.37155146], [50.83704816, 4.37144221], [50.83697346, 4.37132344], [50.83685746, 4.37116559], [50.83678141, 4.37108119], [50.83668405, 4.37102208], [50.83658812, 4.37100577], [50.83646686, 4.37099947], [50.83639389, 4.3710999], [50.83631156, 4.37119878], [50.83620855, 4.3712519], [50.83625922, 4.3714141], [50.83616713, 4.37141469], [50.83607425, 4.37137634], [50.83598022, 4.3713927], [50.83596981, 4.37153728], [50.83588489, 4.37178558], [50.83592838, 4.37206725], [50.83591319, 4.37223001], [50.83588761, 4.37239493], [50.83601676, 4.37236584], [50.83592629, 4.37239915], [50.83627378, 4.37240136], [50.83642243, 4.37279678], [50.83611751, 4.37281093], [50.83610681, 4.37313828], [50.83604434, 4.37331972], [50.83608344, 4.3735259], [50.83602948, 4.37368998], [50.83600851, 4.37383127], [50.83581476, 4.3743896], [50.83578143, 4.37461816], [50.8357766, 4.37482907], [50.83574675, 4.37502528], [50.83573204, 4.37523101], [50.83570146, 4.37545713], [50.83567685, 4.37568759], [50.83566847, 4.3758629], [50.83566775, 4.37604265], [50.83568676, 4.37623068], [50.83567983, 4.37642243], [50.83566479, 4.37656895], [50.83567009, 4.37677529], [50.83570644, 4.37695045], [50.83574285, 4.37709535], [50.83578632, 4.37727565], [50.83581059, 4.37741236], [50.83582602, 4.3775702], [50.83572847, 4.37718634], [50.83574849, 4.37732695], [50.83576467, 4.37747824], [50.83570977, 4.37790905], [50.83571406, 4.37811266], [50.8357295, 4.37835684], [50.83577068, 4.37852527], [50.83580366, 4.37870705], [50.83580988, 4.37886009], [50.83589362, 4.37866855], [50.8359165, 4.37901709], [50.83596189, 4.37915593], [50.83595786, 4.37934247], [50.83593385, 4.37952955], [50.83582931, 4.37997603], [50.83578896, 4.38013981], [50.83575159, 4.3802808], [50.83567325, 4.38038755], [50.83562943, 4.3805543], [50.83557281, 4.38070382], [50.83552448, 4.38087551], [50.83547926, 4.38099882], [50.83542408, 4.38113558], [50.83535096, 4.38133729], [50.83529936, 4.38151301], [50.83524559, 4.38167556], [50.83522967, 4.38190476], [50.83521253, 4.38209545], [50.83511085, 4.38217074], [50.8349952, 4.38229181], [50.83491337, 4.38244811], [50.83485709, 4.38261435], [50.8348236, 4.3828037], [50.83473315, 4.38314985], [50.83467203, 4.3833659], [50.83463237, 4.38351405], [50.83459122, 4.38366051], [50.83453001, 4.38380322], [50.83448324,

# %%
outlier_df = trajectory_df.reset_index().merge(cleaned_df.reset_index(), on=['DateTime'], how='left', indicator=True)
outlier_df = outlier_df[outlier_df["_merge"] == "left_only"]
outlier_df
# Out:
#     traj_id_x                  DateTime      lat_x     lon_x  distance_x  \
# 0           0 2023-06-30 13:34:13+00:00  50.839978  4.365087    6.434879
# 45          0 2023-06-30 13:37:32+00:00  50.839175  4.371870   16.647453
# 64          0 2023-06-30 13:38:53+00:00  50.837625  4.372092   11.784644
# 98          0 2023-06-30 13:41:56+00:00  50.835857  4.374173    0.858093
# 120         0 2023-06-30 13:43:03+00:00  50.835689  4.377672   13.564840
# 132         0 2023-06-30 13:43:41+00:00  50.835871  4.379739    6.307232
# 152         0 2023-06-30 13:44:49+00:00  50.834753  4.383009    0.930106
# 292         0 2023-06-30 13:55:01+00:00  50.823541  4.401665    8.955597
#
#      is normal_x  Distance_x    Speed_x traj_id_y  lat_y  lon_y  distance_y  \
# 0          False         NaN        NaN       NaN    NaN    NaN         NaN
# 45         False   14.536831  14.536831       NaN    NaN    NaN         NaN
# 64         False   19.286196  19.286196       NaN    NaN    NaN         NaN
# 98          True   29.308207  14.654104       NaN    NaN    NaN         NaN
# 120        False   15.983280  15.983280       NaN    NaN    NaN         NaN
# 132        False   16.253435  16.253435       NaN    NaN    NaN         NaN
# 152         True   16.437426  16.437426       NaN    NaN    NaN         NaN
# 292        False   16.051997  16.051997       NaN    NaN    NaN         NaN
#
#     is normal_y  Distance_y  Speed_y     _merge
# 0           NaN         NaN      NaN  left_only
# 45          NaN         NaN      NaN  left_only
# 64          NaN         NaN      NaN  left_only
# 98          NaN         NaN      NaN  left_only
# 120         NaN         NaN      NaN  left_only
# 132         NaN         NaN      NaN  left_only
# 152         NaN         NaN      NaN  left_only
# 292         NaN         NaN      NaN  left_only

# %%
TP = len(cleaned_df[cleaned_df["is normal"] == True])
FP = len(cleaned_df[cleaned_df["is normal"] == False])
TN = len(outlier_df[outlier_df["is normal_x"] == False])
FN = len(outlier_df[outlier_df["is normal_x"] == True])

print("TP:{}\nFP:{}\nTN:{}\nFN:{}".format(TP,FP,TN,FN))
print("Precision:", TP / (TP + FP))
print("Accuracy::",(TP + TN) / (TP + TN + FP + FN))
print("Recall:", TP / (TP + FN))
# Out:
# TP:99
# FP:210
# TN:6
# FN:2
# Precision: 0.32038834951456313
# Accuracy:: 0.3312302839116719
# Recall: 0.9801980198019802

# %% [markdown]
# ## Qualititative analysis based on the introduction of outliers

# %% [markdown]
# ### Ground truth computation

# %%
PROB = 0.99
EPS = 10**(-3)
df= pd.read_csv("datasets/cars_sample.csv")
variation_lat = np.zeros(len(df))
variation_lon = np.zeros(len(df))
is_normal = np.zeros(len(df))
for i in range(len(variation_lat)):
    p = np.random.random()
    if p > PROB:
        variation_lat[i] = np.random.random()*EPS
    p = np.random.random()
    if p > PROB:
        variation_lon[i] = np.random.random()*EPS
    if variation_lat[i] == 0 and variation_lon[i] == 0:
        is_normal[i] = 1
df["Latitude"] += variation_lat
df["Longitude"] += variation_lon
df["is normal"] = is_normal > 0
df = df.rename(columns={"Longitude": "longitude", "Latitude": "latitude", "Timestamp": "time"})
df
# Out:
#         id                           time   latitude  longitude  is normal
# 0        8     2020-06-01 08:56:08.148+00  50.861073   4.465373       True
# 1        8     2020-06-01 08:56:09.648+00  50.861100   4.465386       True
# 2        8     2020-06-01 08:56:10.398+00  50.861127   4.465398       True
# 3        8  2020-06-01 08:56:10.797745+00  50.861146   4.465406       True
# 4        8  2020-06-01 08:56:24.229685+00  50.861756   4.465684       True
# ...    ...                            ...        ...        ...        ...
# 40318  141  2020-06-01 22:13:04.924541+00  50.860548   4.493296       True
# 40319  141  2020-06-01 22:13:06.924541+00  50.860522   4.493314       True
# 40320  141  2020-06-01 22:13:07.781683+00  50.860496   4.493333       True
# 40321  141   2020-06-01 22:13:09.04435+00  50.860442   4.493372       True
# 40322  141  2020-06-01 22:13:14.667066+00  50.860205   4.493563       True
#
# [40323 rows x 5 columns]

# %%
df= pd.read_csv("datasets/berlinMOD_sample_.csv")
trajectory_df = PTRAILDataFrame(data_set = df, latitude='latitude', longitude='longitude', datetime='time', traj_id='id')

# %% [markdown]
# #### Hampel based method

# %%
trajectory_df = kinematic.create_speed_column(trajectory_df)
cleaned_df= filt.hampel_outlier_detection(dataframe=trajectory_df, column_name='Speed')
cleaned_df
# Out:
# Process Process-15:
# multiprocessing.pool.RemoteTraceback:
# """
# Traceback (most recent call last):
#   File "/home/pierre-cedric/miniconda3/envs/ptrail/lib/python3.9/multiprocessing/pool.py", line 125, in worker
#     result = (True, func(*args, **kwds))
#   File "/home/pierre-cedric/miniconda3/envs/ptrail/lib/python3.9/multiprocessing/pool.py", line 51, in starmapstar
#     return list(itertools.starmap(args[0], args[1]))
#   File "/home/pierre-cedric/miniconda3/envs/ptrail/lib/python3.9/site-packages/ptrail/preprocessing/helpers.py", line 390, in hampel_help
#     to_return = df.drop(df.index[outlier_indices])
#   File "/home/pierre-cedric/miniconda3/envs/ptrail/lib/python3.9/site-packages/pandas/core/indexes/base.py", line 5382, in __getitem__
#     result = getitem(key)
# IndexError: only integers, slices (`:`), ellipsis (`...`), numpy.newaxis (`None`) and integer or boolean arrays are valid indices
# """
#
# The above exception was the direct cause of the following exception:
#
# Traceback (most recent call last):
#   File "/home/pierre-cedric/miniconda3/envs/ptrail/lib/python3.9/multiprocessing/process.py", line 315, in _bootstrap
#     self.run()
#   File "/home/pierre-cedric/miniconda3/envs/ptrail/lib/python3.9/multiprocessing/process.py", line 108, in run
#     self._target(*self._args, **self._kwargs)
#   File "/home/pierre-cedric/miniconda3/envs/ptrail/lib/python3.9/site-packages/ptrail/preprocessing/filters.py", line 754, in _hampel
#     final = small_pool.starmap(helper.hampel_help,
#   File "/home/pierre-cedric/miniconda3/envs/ptrail/lib/python3.9/multiprocessing/pool.py", line 372, in starmap
#     return self._map_async(func, iterable, starmapstar, chunksize).get()
#   File "/home/pierre-cedric/miniconda3/envs/ptrail/lib/python3.9/multiprocessing/pool.py", line 771, in get
#     raise self._value
# IndexError: only integers, slices (`:`), ellipsis (`...`), numpy.newaxis (`None`) and integer or boolean arrays are valid indices
# Process Process-14:
# multiprocessing.pool.RemoteTraceback:
# """
# Traceback (most recent call last):
#   File "/home/pierre-cedric/miniconda3/envs/ptrail/lib/python3.9/multiprocessing/pool.py", line 125, in worker
#     result = (True, func(*args, **kwds))
#   File "/home/pierre-cedric/miniconda3/envs/ptrail/lib/python3.9/multiprocessing/pool.py", line 51, in starmapstar
#     return list(itertools.starmap(args[0], args[1]))
#   File "/home/pierre-cedric/miniconda3/envs/ptrail/lib/python3.9/site-packages/ptrail/preprocessing/helpers.py", line 390, in hampel_help
#     to_return = df.drop(df.index[outlier_indices])
#   File "/home/pierre-cedric/miniconda3/envs/ptrail/lib/python3.9/site-packages/pandas/core/indexes/base.py", line 5382, in __getitem__
#     result = getitem(key)
# IndexError: only integers, slices (`:`), ellipsis (`...`), numpy.newaxis (`None`) and integer or boolean arrays are valid indices
# """
#
# The above exception was the direct cause of the following exception:
#
# Traceback (most recent call last):
#   File "/home/pierre-cedric/miniconda3/envs/ptrail/lib/python3.9/multiprocessing/process.py", line 315, in _bootstrap
#     self.run()
#   File "/home/pierre-cedric/miniconda3/envs/ptrail/lib/python3.9/multiprocessing/process.py", line 108, in run
#     self._target(*self._args, **self._kwargs)
#   File "/home/pierre-cedric/miniconda3/envs/ptrail/lib/python3.9/site-packages/ptrail/preprocessing/filters.py", line 754, in _hampel
#     final = small_pool.starmap(helper.hampel_help,
#   File "/home/pierre-cedric/miniconda3/envs/ptrail/lib/python3.9/multiprocessing/pool.py", line 372, in starmap
#     return self._map_async(func, iterable, starmapstar, chunksize).get()
#   File "/home/pierre-cedric/miniconda3/envs/ptrail/lib/python3.9/multiprocessing/pool.py", line 771, in get
#     raise self._value
# IndexError: only integers, slices (`:`), ellipsis (`...`), numpy.newaxis (`None`) and integer or boolean arrays are valid indices
# /home/pierre-cedric/miniconda3/envs/ptrail/lib/python3.9/site-packages/ptrail/preprocessing/filters.py:726: UserWarning: If kinematic features have been generated on the dataframe, then make sure to generate them again as outlier detection drops the point from the dataframe and does not run the kinematic features again.
#   warnings.warn("If kinematic features have been generated on the dataframe, then make "
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[21], line 2
#       1 trajectory_df = kinematic.create_speed_column(trajectory_df)
# ----> 2 cleaned_df= filt.hampel_outlier_detection(dataframe=trajectory_df, column_name='Speed')
#       3 cleaned_df
#
# File ~/miniconda3/envs/ptrail/lib/python3.9/site-packages/ptrail/preprocessing/filters.py:731, in Filters.hampel_outlier_detection(dataframe, column_name)
#     726 warnings.warn("If kinematic features have been generated on the dataframe, then make "
#     727               "sure to generate them again as outlier detection drops the point from "
#     728               "the dataframe and does not run the kinematic features again.")
#     730 # Convert the results back to PTRAILDataFrame and return the resultant dataframe.
# --> 731 return PTRAILDataFrame(pd.concat(return_list),
#     732                        const.LAT, const.LONG, const.DateTime, const.TRAJECTORY_ID)
#
# File ~/miniconda3/envs/ptrail/lib/python3.9/site-packages/pandas/core/reshape/concat.py:380, in concat(objs, axis, join, ignore_index, keys, levels, names, verify_integrity, sort, copy)
#     377 elif copy and using_copy_on_write():
#     378     copy = False
# --> 380 op = _Concatenator(
#     381     objs,
#     382     axis=axis,
#     383     ignore_index=ignore_index,
#     384     join=join,
#     385     keys=keys,
#     386     levels=levels,
#     387     names=names,
#     388     verify_integrity=verify_integrity,
#     389     copy=copy,
#     390     sort=sort,
#     391 )
#     393 return op.get_result()
#
# File ~/miniconda3/envs/ptrail/lib/python3.9/site-packages/pandas/core/reshape/concat.py:443, in _Concatenator.__init__(self, objs, axis, join, keys, levels, names, ignore_index, verify_integrity, copy, sort)
#     440 self.verify_integrity = verify_integrity
#     441 self.copy = copy
# --> 443 objs, keys = self._clean_keys_and_objs(objs, keys)
#     445 # figure out what our result ndim is going to be
#     446 ndims = self._get_ndims(objs)
#
# File ~/miniconda3/envs/ptrail/lib/python3.9/site-packages/pandas/core/reshape/concat.py:505, in _Concatenator._clean_keys_and_objs(self, objs, keys)
#     502     objs_list = list(objs)
#     504 if len(objs_list) == 0:
# --> 505     raise ValueError("No objects to concatenate")
#     507 if keys is None:
#     508     objs_list = list(com.not_none(*objs_list))
#
# ValueError: No objects to concatenate

# %%
outlier_df = trajectory_df.reset_index().merge(cleaned_df.reset_index(), on=['DateTime'], how='left', indicator=True)
outlier_df = outlier_df[outlier_df["_merge"] == "left_only"]
outlier_df
# Out:
#       traj_id_x                         DateTime      lat_x     lon_x  \
# 0           141 2020-06-01 08:25:35.332000+00:00  50.860205  4.493563
# 1           141 2020-06-01 08:25:36.832000+00:00  50.860231  4.493543
# 2           141 2020-06-01 08:25:37.582000+00:00  50.860256  4.493522
# 3           141 2020-06-01 08:25:39.382000+00:00  50.860332  4.493461
# 4           141 2020-06-01 08:25:40.305076+00:00  50.860357  4.493440
# ...         ...                              ...        ...       ...
# 40318         8 2020-06-04 21:56:59.514958+00:00  50.861842  4.465724
# 40319         8 2020-06-04 21:56:59.943340+00:00  50.861822  4.465716
# 40320         8 2020-06-04 21:57:01.415195+00:00  50.861756  4.465684
# 40321         8 2020-06-04 21:57:14.847135+00:00  50.861146  4.465406
# 40322         8 2020-06-04 21:57:16.446880+00:00  50.861073  4.465373
#
#        is normal_x  Distance_x   Speed_x traj_id_y  lat_y  lon_y  distance  \
# 0             True         NaN       NaN       NaN    NaN    NaN       NaN
# 1             True    3.152541  2.101694       NaN    NaN    NaN       NaN
# 2             True    3.152539  4.203386       NaN    NaN    NaN       NaN
# 3             True    9.457607  5.254226       NaN    NaN    NaN       NaN
# 4             True    3.152532  3.415247       NaN    NaN    NaN       NaN
# ...            ...         ...       ...       ...    ...    ...       ...
# 40318         True    1.174545  4.203256       NaN    NaN    NaN       NaN
# 40319         True    2.250746  5.254062       NaN    NaN    NaN       NaN
# 40320         True    7.733216  5.254061       NaN    NaN    NaN       NaN
# 40321         True   70.572705  5.254096       NaN    NaN    NaN       NaN
# 40322         True    8.405279  5.254137       NaN    NaN    NaN       NaN
#
#       is normal_y  Distance_y  Speed_y     _merge
# 0             NaN         NaN      NaN  left_only
# 1             NaN         NaN      NaN  left_only
# 2             NaN         NaN      NaN  left_only
# 3             NaN         NaN      NaN  left_only
# 4             NaN         NaN      NaN  left_only
# ...           ...         ...      ...        ...
# 40318         NaN         NaN      NaN  left_only
# 40319         NaN         NaN      NaN  left_only
# 40320         NaN         NaN      NaN  left_only
# 40321         NaN         NaN      NaN  left_only
# 40322         NaN         NaN      NaN  left_only
#
# [40323 rows x 15 columns]

# %%
TP = len(cleaned_df[cleaned_df["is normal"] == True])
FP = len(cleaned_df[cleaned_df["is normal"] == False])
TN = len(outlier_df[outlier_df["is normal_x"] == False])
FN = len(outlier_df[outlier_df["is normal_x"] == True])

print("TP:{}\nFP:{}\nTN:{}\nFN:{}".format(TP,FP,TN,FN))
print("Precision:", TP / (TP + FP))
print("Accuracy::",(TP + TN) / (TP + TN + FP + FN))
print("Recall:", TP / (TP + FN))
# Out:
# TP:99
# FP:210
# TN:845
# FN:39478
# Precision: 0.32038834951456313
# Accuracy:: 0.02323291986611538
# Recall: 0.0025014528640371933

# %% [markdown]
# #### IQR based  method

# %%
cleaned_df = filt.filter_outliers_by_consecutive_speed(dataframe=trajectory_df)

# %%
outlier_df = trajectory_df.reset_index().merge(cleaned_df.reset_index(), on=['DateTime'], how='left', indicator=True)
outlier_df = outlier_df[outlier_df["_merge"] == "left_only"]
outlier_df
# Out:
#       traj_id_x                         DateTime      lat_x     lon_x  \
# 0           141 2020-06-01 08:25:35.332000+00:00  50.860205  4.493563
# 11          141 2020-06-01 08:26:00.854047+00:00  50.861914  4.492638
# 120         141 2020-06-01 08:29:14.471114+00:00  50.856244  4.485793
# 121         141 2020-06-01 08:29:14.971114+00:00  50.856216  4.484857
# 351         141 2020-06-01 08:34:07.872222+00:00  50.850572  4.480175
# ...         ...                              ...        ...       ...
# 40071         8 2020-06-04 20:48:31.659883+00:00  50.862079  4.465729
# 40100         8 2020-06-04 20:49:17.632206+00:00  50.862688  4.464107
# 40118         8 2020-06-04 20:49:40.899044+00:00  50.862854  4.463572
# 40130         8 2020-06-04 20:49:50.090916+00:00  50.864079  4.463321
# 40131         8 2020-06-04 20:49:50.454107+00:00  50.863122  4.463292
#
#        is normal_x  Distance_x      Speed_x traj_id_y  lat_y  lon_y  \
# 0             True         NaN          NaN       NaN    NaN    NaN
# 11           False  101.645187   160.938454       NaN    NaN    NaN
# 120          False   64.764284    86.352379       NaN    NaN    NaN
# 121           True   65.753658   131.507315       NaN    NaN    NaN
# 351          False  102.275599    94.698401       NaN    NaN    NaN
# ...            ...         ...          ...       ...    ...    ...
# 40071        False   26.376513    47.195729       NaN    NaN    NaN
# 40100        False   50.780428    70.528372       NaN    NaN    NaN
# 40118         True   20.785274    34.642123       NaN    NaN    NaN
# 40130        False  109.289269  1041.971545       NaN    NaN    NaN
# 40131         True  106.365800   292.864636       NaN    NaN    NaN
#
#       is normal_y  Distance_y  Speed_y     _merge
# 0             NaN         NaN      NaN  left_only
# 11            NaN         NaN      NaN  left_only
# 120           NaN         NaN      NaN  left_only
# 121           NaN         NaN      NaN  left_only
# 351           NaN         NaN      NaN  left_only
# ...           ...         ...      ...        ...
# 40071         NaN         NaN      NaN  left_only
# 40100         NaN         NaN      NaN  left_only
# 40118         NaN         NaN      NaN  left_only
# 40130         NaN         NaN      NaN  left_only
# 40131         NaN         NaN      NaN  left_only
#
# [1278 rows x 14 columns]

# %%
TP = len(cleaned_df[cleaned_df["is normal"] == True])
FP = len(cleaned_df[cleaned_df["is normal"] == False])
TN = len(outlier_df[outlier_df["is normal_x"] == False])
FN = len(outlier_df[outlier_df["is normal_x"] == True])

print("TP:{}\nFP:{}\nTN:{}\nFN:{}".format(TP,FP,TN,FN))
print("Precision:", TP / (TP + FP))
print("Accuracy::",(TP + TN) / (TP + TN + FP + FN))
print("Recall:", TP / (TP + FN))
# Out:
# TP:38849
# FP:196
# TN:649
# FN:629
# Precision: 0.9949801511076962
# Accuracy:: 0.979540212781787
# Recall: 0.9840670753330969
