# %%
"""
Function to compute the execution time.
"""
from datetime import timedelta
import time
def get_time(f, kwargs={}):
    times = []
    result = None
    for i in range(1):
        print("\nmeasure",i+1)
        t = time.time()
        result = f(**kwargs)
        res = time.time()-t
        times.append(res)
        print( timedelta(seconds=res))
        if res > 3600*2:
            print("trop de temps")
            return result
        
    print("\nall times:", times)
    a = min(times)
    b = max(times)
    print("times' outliers:",a,"&",b)
    t = abs(sum(times)-a-b)/1
    print("benchmark time",str(t)+"s","or", timedelta(seconds=t))
    return result

# %%
import matplotlib.pyplot as plt
import pandas as pd
from pymeos import *

pymeos_initialize()

# %%
SIZE = "large"

# %% [markdown]
# # Cars Trajectories

# %%
PATH='../../datasets/cars_'+SIZE+'.csv'
df = pd.read_csv(PATH)
df = df.dropna()
df["Timestamp"] = pd.to_datetime(df["Timestamp"],format='mixed')
df = df.drop_duplicates(["Timestamp"])
df = df.sort_values(by= "Timestamp")
df['point'] = df.apply(lambda row: TGeogPointInst(point=(row['Latitude'], row['Longitude']), timestamp=row['Timestamp']),axis=1)
df.drop(['Latitude', 'Longitude'], axis=1, inplace=True)
trajectories = df.groupby('id').aggregate(
    {
        'point': TGeogPointSeq.from_instants,
    }
).rename({'point': 'trajectory'}, axis=1)
size = len(trajectories)
size
# Out:
# 447

# %%
tt_size = 0
for i in range(size):
    tt_size+=trajectories["trajectory"].values[i].num_instants()
tt_size

# %%
# trajectories["trajectory"].iloc[0].simplify(0.00001,True)
# Out:
# TGeogPointSeq([0101000020E6100000BD14C37A48624940275FAEEA51BD1140@2020-06-01 11:54:52.511+02, 0101000020E61000009C495D4C48624940B2E71E5E46BD1140@2020-06-01 11:54:54.011+02, 0101000020E61000001F7EF71D486249403E708FD13ABD1140@2020-06-01 11:54:54.911+02, 0101000020E61000000551F7014862494050604BD933BD1140@2020-06-01 11:55:02.842104+02, 0101000020E610000025B6BCA247624940B860300E29BD1140@2020-06-01 11:55:04.188436+02, 0101000020E610000022BE95D041624940138B4D1088BC1140@2020-06-01 11:55:17.935644+02, 0101000020E61000005595EB6241624940D2DE329C7DBC1140@2020-06-01 11:55:20.185644+02, 0101000020E61000007D282C4C3A62494006C73258CCBB1140@2020-06-01 11:55:35.370275+02, 0101000020E61000000BE3AB1E35624940DA9B4F1235BB1140@2020-06-01 11:55:47.970275+02, 0101000020E6100000FF1BFEBF34624940C6182D442ABB1140@2020-06-01 11:55:49.770275+02, 0101000020E6100000AA274E4931624940D627C412C5BA1140@2020-06-01 11:55:58.512505+02, 0101000020E610000098D0C61E2C624940B097F46014BA1140@2020-06-01 11:56:12.912505+02, 0101000020E610000075511ECC2B624940AE9ED75509BA1140@2020-06-01 11:56:14.712505+02, 0101000020E610000031CD24D42A624940A7B38034E8B91140@2020-06-01 11:56:17.412505+02, 0101000020E61000007E497C812A624940A4BA6329DDB91140@2020-06-01 11:56:19.983933+02, 0101000020E610000001D6D78723624940541F0468F2B81140@2020-06-01 11:56:39.201847+02, 0101000020E6100000F14CD477236249400A044070F0B81140@2020-06-01 11:56:41.062828+02, 0101000020E6100000D20660032262494003C46EE9E2B81140@2020-06-01 11:56:43.265653+02, 0101000020E6100000ECA67F152162494027617434E2B81140@2020-06-01 11:56:44.165653+02, 0101000020E610000010584AE0206249408132F90BE2B81140@2020-06-01 11:56:45.793098+02, 0101000020E6100000B6AB7B781C6249400031C40AF5B81140@2020-06-01 11:56:50.63671+02, 0101000020E61000004B9759DF1B6249406D6E089FF7B81140@2020-06-01 11:56:52.67378+02, 0101000020E6100000E74ABAF114624940E619BC2A1AB91140@2020-06-01 11:56:59.87378+02, 0101000020E61000006B3C061414624940558F327C1EB91140@2020-06-01 11:57:01.37378+02, 0101000020E61000003A95DED108624940FB85369F56B91140@2020-06-01 11:57:13.07378+02, 0101000020E610000079735D9D08624940668302A557B91140@2020-06-01 11:57:15.036515+02, 0101000020E6100000ED889EEF02624940A449E53796B91140@2020-06-01 11:57:23.018245+02, 0101000020E610000082E1C76E00624940E63CC015B9B91140@2020-06-01 11:57:26.618245+02, 0101000020E6100000F02C92CEFF614940B5F936CDC1B91140@2020-06-01 11:57:31.118245+02, 0101000020E6100000F0B6268EFE6149405873243CD3B91140@2020-06-01 11:57:34.288699+02, 0101000020E6100000E4260FB0FB614940C90FF6DCF8B91140@2020-06-01 11:57:38.284134+02, 0101000020E6100000ADA59422FC614940478AD8B80FBA1140@2020-06-01 11:57:39.255724+02, 0101000020E610000043221A95FC614940C404BB9426BA1140@2020-06-01 11:57:39.975724+02, 0101000020E610000002B04B9EFC614940E154826A28BA1140@2020-06-01 11:57:40.601564+02, 0101000020E6100000EEE43307FD614940100329633FBA1140@2020-06-01 11:57:41.851564+02, 0101000020E61000002480F67EFE61494014CFB7AA91BA1140@2020-06-01 11:57:44.517509+02, 0101000020E6100000C5092BFDFE614940777B0760A8BA1140@2020-06-01 11:57:45.426344+02, 0101000020E6100000A1AA2323066249401DBF0AA5F1BB1140@2020-06-01 11:57:55.866344+02, 0101000020E6100000D96D6127066249405CC86768F2BB1140@2020-06-01 11:57:56.769005+02, 0101000020E6100000F8BC967906624940BD4EA075FDBB1140@2020-06-01 11:57:58.118301+02, 0101000020E6100000D057011E076249407E5B119013BC1140@2020-06-01 11:57:59.310685+02, 0101000020E61000009C37A11408624940A2EEBAB734BC1140@2020-06-01 11:58:00.395498+02, 0101000020E61000009B91F760086249404A92E7FA3EBC1140@2020-06-01 11:58:08.008512+02, 0101000020E6100000BD3027D1086249409D69435E49BC1140@2020-06-01 11:58:09.276517+02, 0101000020E6100000B56886B1096249404418FB245EBC1140@2020-06-01 11:58:10.434916+02, 0101000020E61000004398E5910A624940EAC6B2EB72BC1140@2020-06-01 11:58:11.154916+02, 0101000020E61000004398E5910A624940EAC6B2EB72BC1140@2020-06-01 11:58:12.33134+02, 0101000020E6100000860079420B62494011B007E981BC1140@2020-06-01 11:58:13.79154+02, 0101000020E61000000B01C5AB0D624940C9231844B4BC1140@2020-06-01 11: ...

# %%
tolerance = 1/111139
compressed = trajectories.copy()
compressed["trajectory"] = compressed["trajectory"].apply(lambda x:x.simplify(tolerance,True))
#compressed
#compressed["trajectory"].values[1].plot()

# %%
tt_size = 0
for i in range(size):
    tt_size+=len(compressed["trajectory"].values[i].to_dataframe())
tt_size

# %%
tt_size = 0
for i in range(size):
    tt_size+=compressed["trajectory"].values[i].num_instants()
tt_size
# Out:
# 5210424

# %%
pymeos_finalize()
